# %%
import pandas as pd

# %%
df = pd.read_excel(r"/Users/saideexith/datacleaning/Amazon Dashboard/Amazon Sale Report - YT.xlsx")
df
# Out:
#                  Unnamed: 0           Sales Data  \
# 0                  Order ID                 Date
# 1       405-8078784-5731545  2022-04-30 00:00:00
# 2       171-9198151-1101146  2022-04-30 00:00:00
# 3       404-0687676-7273146  2022-04-30 00:00:00
# 4       403-9615377-8133951  2022-04-30 00:00:00
# ...                     ...                  ...
# 128971  406-6001380-7673107  2022-05-31 00:00:00
# 128972  402-9551604-7544318  2022-05-31 00:00:00
# 128973  407-9547469-3152358  2022-05-31 00:00:00
# 128974  402-6184140-0545956  2022-05-31 00:00:00
# 128975  408-7436540-8728312  2022-05-31 00:00:00
#
#                           Unnamed: 2  Unnamed: 3      Unnamed: 4  \
# 0                             Status  Fulfilment  Sales Channel
# 1                          Cancelled    Merchant       Amazon.in
# 2       Shipped - Delivered to Buyer    Merchant       Amazon.in
# 3                            Shipped      Amazon       Amazon.in
# ...

# %%
df.drop_duplicates()
# Out:
#                  Unnamed: 0           Sales Data  \
# 0                  Order ID                 Date
# 1       405-8078784-5731545  2022-04-30 00:00:00
# 2       171-9198151-1101146  2022-04-30 00:00:00
# 3       404-0687676-7273146  2022-04-30 00:00:00
# 4       403-9615377-8133951  2022-04-30 00:00:00
# ...                     ...                  ...
# 128971  406-6001380-7673107  2022-05-31 00:00:00
# 128972  402-9551604-7544318  2022-05-31 00:00:00
# 128973  407-9547469-3152358  2022-05-31 00:00:00
# 128974  402-6184140-0545956  2022-05-31 00:00:00
# 128975  408-7436540-8728312  2022-05-31 00:00:00
#
#                           Unnamed: 2  Unnamed: 3      Unnamed: 4  \
# 0                             Status  Fulfilment  Sales Channel
# 1                          Cancelled    Merchant       Amazon.in
# 2       Shipped - Delivered to Buyer    Merchant       Amazon.in
# 3                            Shipped      Amazon       Amazon.in
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#                  Unnamed: 0           Sales Data  \
# 0                  Order ID                 Date
# 1       405-8078784-5731545  2022-04-30 00:00:00
# 2       171-9198151-1101146  2022-04-30 00:00:00
# 3       404-0687676-7273146  2022-04-30 00:00:00
# 4       403-9615377-8133951  2022-04-30 00:00:00
# ...                     ...                  ...
# 128971  406-6001380-7673107  2022-05-31 00:00:00
# 128972  402-9551604-7544318  2022-05-31 00:00:00
# 128973  407-9547469-3152358  2022-05-31 00:00:00
# 128974  402-6184140-0545956  2022-05-31 00:00:00
# 128975  408-7436540-8728312  2022-05-31 00:00:00
#
#                           Unnamed: 2  Unnamed: 3      Unnamed: 4  \
# 0                             Status  Fulfilment  Sales Channel
# 1                          Cancelled    Merchant       Amazon.in
# 2       Shipped - Delivered to Buyer    Merchant       Amazon.in
# 3                            Shipped      Amazon       Amazon.in
# ...

# %%
df.drop(columns = "Unnamed: 13")
# Out:
#                  Unnamed: 0           Sales Data  \
# 0                  Order ID                 Date
# 1       405-8078784-5731545  2022-04-30 00:00:00
# 2       171-9198151-1101146  2022-04-30 00:00:00
# 3       404-0687676-7273146  2022-04-30 00:00:00
# 4       403-9615377-8133951  2022-04-30 00:00:00
# ...                     ...                  ...
# 128971  406-6001380-7673107  2022-05-31 00:00:00
# 128972  402-9551604-7544318  2022-05-31 00:00:00
# 128973  407-9547469-3152358  2022-05-31 00:00:00
# 128974  402-6184140-0545956  2022-05-31 00:00:00
# 128975  408-7436540-8728312  2022-05-31 00:00:00
#
#                           Unnamed: 2  Unnamed: 3      Unnamed: 4  \
# 0                             Status  Fulfilment  Sales Channel
# 1                          Cancelled    Merchant       Amazon.in
# 2       Shipped - Delivered to Buyer    Merchant       Amazon.in
# 3                            Shipped      Amazon       Amazon.in
# ...

# %%
df = df.drop(columns = "Unnamed: 13")

# %%
df = df.drop(columns = "Unnamed: 17")

# %%
df
# Out:
#                  Unnamed: 0           Sales Data  \
# 0                  Order ID                 Date
# 1       405-8078784-5731545  2022-04-30 00:00:00
# 2       171-9198151-1101146  2022-04-30 00:00:00
# 3       404-0687676-7273146  2022-04-30 00:00:00
# 4       403-9615377-8133951  2022-04-30 00:00:00
# ...                     ...                  ...
# 128971  406-6001380-7673107  2022-05-31 00:00:00
# 128972  402-9551604-7544318  2022-05-31 00:00:00
# 128973  407-9547469-3152358  2022-05-31 00:00:00
# 128974  402-6184140-0545956  2022-05-31 00:00:00
# 128975  408-7436540-8728312  2022-05-31 00:00:00
#
#                           Unnamed: 2  Unnamed: 3      Unnamed: 4  \
# 0                             Status  Fulfilment  Sales Channel
# 1                          Cancelled    Merchant       Amazon.in
# 2       Shipped - Delivered to Buyer    Merchant       Amazon.in
# 3                            Shipped      Amazon       Amazon.in
# ...

# %%
df = df.drop(columns="Unnamed: 16")

# %%
df = df.drop(columns = "Unnamed: 7")

# %%
df = df.drop(columns = "Unnamed: 6")

# %%
df = df.drop(columns = "Unnamed: 10")

# %%
df
# Out:
#                  Unnamed: 0           Sales Data  \
# 0                  Order ID                 Date
# 1       405-8078784-5731545  2022-04-30 00:00:00
# 2       171-9198151-1101146  2022-04-30 00:00:00
# 3       404-0687676-7273146  2022-04-30 00:00:00
# 4       403-9615377-8133951  2022-04-30 00:00:00
# ...                     ...                  ...
# 128971  406-6001380-7673107  2022-05-31 00:00:00
# 128972  402-9551604-7544318  2022-05-31 00:00:00
# 128973  407-9547469-3152358  2022-05-31 00:00:00
# 128974  402-6184140-0545956  2022-05-31 00:00:00
# 128975  408-7436540-8728312  2022-05-31 00:00:00
#
#                           Unnamed: 2  Unnamed: 3      Unnamed: 4  \
# 0                             Status  Fulfilment  Sales Channel
# 1                          Cancelled    Merchant       Amazon.in
# 2       Shipped - Delivered to Buyer    Merchant       Amazon.in
# 3                            Shipped      Amazon       Amazon.in
# ...

# %%
df = df.drop(columns = "Unnamed: 0")

# %%
df
# Out:
#                  Sales Data                    Unnamed: 2  Unnamed: 3  \
# 0                      Date                        Status  Fulfilment
# 1       2022-04-30 00:00:00                     Cancelled    Merchant
# 2       2022-04-30 00:00:00  Shipped - Delivered to Buyer    Merchant
# 3       2022-04-30 00:00:00                       Shipped      Amazon
# 4       2022-04-30 00:00:00                     Cancelled    Merchant
# ...                     ...                           ...         ...
# 128971  2022-05-31 00:00:00                       Shipped      Amazon
# 128972  2022-05-31 00:00:00                       Shipped      Amazon
# 128973  2022-05-31 00:00:00                       Shipped      Amazon
# 128974  2022-05-31 00:00:00                       Shipped      Amazon
# 128975  2022-05-31 00:00:00                       Shipped      Amazon
#
#             Unnamed: 4          Unnamed: 5     Unnamed: 8 Unnamed: 9  \
# ...

# %%
df = df.drop(columns = "Unnamed: 4")

# %%
df
# Out:
#                  Sales Data                    Unnamed: 2  Unnamed: 3  \
# 0                      Date                        Status  Fulfilment
# 1       2022-04-30 00:00:00                     Cancelled    Merchant
# 2       2022-04-30 00:00:00  Shipped - Delivered to Buyer    Merchant
# 3       2022-04-30 00:00:00                       Shipped      Amazon
# 4       2022-04-30 00:00:00                     Cancelled    Merchant
# ...                     ...                           ...         ...
# 128971  2022-05-31 00:00:00                       Shipped      Amazon
# 128972  2022-05-31 00:00:00                       Shipped      Amazon
# 128973  2022-05-31 00:00:00                       Shipped      Amazon
# 128974  2022-05-31 00:00:00                       Shipped      Amazon
# 128975  2022-05-31 00:00:00                       Shipped      Amazon
#
#                 Unnamed: 5     Unnamed: 8 Unnamed: 9     Unnamed: 11  \
# ...

# %%
df["Unnamed: 11"] = df["Unnamed: 11"].fillna('cancelled')

# %%
df
# Out:
#                  Sales Data                    Unnamed: 2  Unnamed: 3  \
# 0                      Date                        Status  Fulfilment
# 1       2022-04-30 00:00:00                     Cancelled    Merchant
# 2       2022-04-30 00:00:00  Shipped - Delivered to Buyer    Merchant
# 3       2022-04-30 00:00:00                       Shipped      Amazon
# 4       2022-04-30 00:00:00                     Cancelled    Merchant
# ...                     ...                           ...         ...
# 128971  2022-05-31 00:00:00                       Shipped      Amazon
# 128972  2022-05-31 00:00:00                       Shipped      Amazon
# 128973  2022-05-31 00:00:00                       Shipped      Amazon
# 128974  2022-05-31 00:00:00                       Shipped      Amazon
# 128975  2022-05-31 00:00:00                       Shipped      Amazon
#
#                 Unnamed: 5     Unnamed: 8 Unnamed: 9     Unnamed: 11  \
# ...

# %%
df = df.drop(columns = "Unnamed: 19")

# %%
df
# Out:
#                  Sales Data                    Unnamed: 2  Unnamed: 3  \
# 0                      Date                        Status  Fulfilment
# 1       2022-04-30 00:00:00                     Cancelled    Merchant
# 2       2022-04-30 00:00:00  Shipped - Delivered to Buyer    Merchant
# 3       2022-04-30 00:00:00                       Shipped      Amazon
# 4       2022-04-30 00:00:00                     Cancelled    Merchant
# ...                     ...                           ...         ...
# 128971  2022-05-31 00:00:00                       Shipped      Amazon
# 128972  2022-05-31 00:00:00                       Shipped      Amazon
# 128973  2022-05-31 00:00:00                       Shipped      Amazon
# 128974  2022-05-31 00:00:00                       Shipped      Amazon
# 128975  2022-05-31 00:00:00                       Shipped      Amazon
#
#                 Unnamed: 5     Unnamed: 8 Unnamed: 9     Unnamed: 11  \
# ...

# %%
df.rename(columns = {'Unnamed: 2':'Status'}, inplace = True)

# %%
df
# Out:
#                  Sales Data                        Status  Unnamed: 3  \
# 0                      Date                        Status  Fulfilment
# 1       2022-04-30 00:00:00                     Cancelled    Merchant
# 2       2022-04-30 00:00:00  Shipped - Delivered to Buyer    Merchant
# 3       2022-04-30 00:00:00                       Shipped      Amazon
# 4       2022-04-30 00:00:00                     Cancelled    Merchant
# ...                     ...                           ...         ...
# 128971  2022-05-31 00:00:00                       Shipped      Amazon
# 128972  2022-05-31 00:00:00                       Shipped      Amazon
# 128973  2022-05-31 00:00:00                       Shipped      Amazon
# 128974  2022-05-31 00:00:00                       Shipped      Amazon
# 128975  2022-05-31 00:00:00                       Shipped      Amazon
#
#                 Unnamed: 5     Unnamed: 8 Unnamed: 9     Unnamed: 11  \
# ...

# %%
df.rename(columns = {'Unnamed: 3':'Fulfilment'}, inplace = True)
df.rename(columns = {'Unnamed: 5':'ship-service-level'}, inplace = True)
df.rename(columns = {'Unnamed: 8':'Category'}, inplace = True)
df.rename(columns = {'Unnamed: 9':'Size'}, inplace = True)
df.rename(columns = {'Unnamed: 11':'Courier Status'}, inplace = True)
df.rename(columns = {'Unnamed: 12':'Quantity'}, inplace = True)
df.rename(columns = {'Unnamed: 14':'ship-city'}, inplace = True)
df.rename(columns = {'Unnamed: 15':'ship-state'}, inplace = True)

# %%
df
# Out:
#                  Sales Data                        Status  Fulfilment  \
# 0                      Date                        Status  Fulfilment
# 1       2022-04-30 00:00:00                     Cancelled    Merchant
# 2       2022-04-30 00:00:00  Shipped - Delivered to Buyer    Merchant
# 3       2022-04-30 00:00:00                       Shipped      Amazon
# 4       2022-04-30 00:00:00                     Cancelled    Merchant
# ...                     ...                           ...         ...
# 128971  2022-05-31 00:00:00                       Shipped      Amazon
# 128972  2022-05-31 00:00:00                       Shipped      Amazon
# 128973  2022-05-31 00:00:00                       Shipped      Amazon
# 128974  2022-05-31 00:00:00                       Shipped      Amazon
# 128975  2022-05-31 00:00:00                       Shipped      Amazon
#
#         ship-service-level       Category  Size  Courier Status Quantity  \
# ...

# %%
df.rename(columns = {'Unnamed: 18':'fulfilled-by'}, inplace = True)

# %%
df = df.drop([0])

# %%
df["fulfilled-by"] = df["fulfilled-by"].fillna('Others')

# %%
df
# Out:
#                  Sales Data                        Status Fulfilment  \
# 1       2022-04-30 00:00:00                     Cancelled   Merchant
# 2       2022-04-30 00:00:00  Shipped - Delivered to Buyer   Merchant
# 3       2022-04-30 00:00:00                       Shipped     Amazon
# 4       2022-04-30 00:00:00                     Cancelled   Merchant
# 5       2022-04-30 00:00:00                       Shipped     Amazon
# ...                     ...                           ...        ...
# 128971  2022-05-31 00:00:00                       Shipped     Amazon
# 128972  2022-05-31 00:00:00                       Shipped     Amazon
# 128973  2022-05-31 00:00:00                       Shipped     Amazon
# 128974  2022-05-31 00:00:00                       Shipped     Amazon
# 128975  2022-05-31 00:00:00                       Shipped     Amazon
#
#        ship-service-level       Category Size Courier Status Quantity  \
# ...

# %%
df
# Out:
#                  Sales Data                        Status Fulfilment  \
# 1       2022-04-30 00:00:00                     Cancelled   Merchant
# 2       2022-04-30 00:00:00  Shipped - Delivered to Buyer   Merchant
# 3       2022-04-30 00:00:00                       Shipped     Amazon
# 4       2022-04-30 00:00:00                     Cancelled   Merchant
# 5       2022-04-30 00:00:00                       Shipped     Amazon
# ...                     ...                           ...        ...
# 128971  2022-05-31 00:00:00                       Shipped     Amazon
# 128972  2022-05-31 00:00:00                       Shipped     Amazon
# 128973  2022-05-31 00:00:00                       Shipped     Amazon
# 128974  2022-05-31 00:00:00                       Shipped     Amazon
# 128975  2022-05-31 00:00:00                       Shipped     Amazon
#
#        ship-service-level       Category Size Courier Status Quantity  \
# ...
